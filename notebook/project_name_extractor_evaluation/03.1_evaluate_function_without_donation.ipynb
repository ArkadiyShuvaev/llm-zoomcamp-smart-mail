# %% [markdown]
# # Evaluating a Function that Extracts Project Names from Customer Emails
#
# Evaluating a function that extracts project names from customer emails requires both **quantitative metrics** and a **systematic approach** to assess its accuracy and performance. Since there is a **ground truth CSV file** containing both the expected project names and the customer email content, we can measure how well the function performs by comparing its outputs with the expected results.

# %% [markdown]
# ### The Evaluation Metrics
# The most appropriate metrics for this task are:
#
# - **Accuracy**: Measures how often the function correctly extracts the project name. It's the ratio of correctly identified project names to the total number of cases.
# - **Precision**: Measures the percentage of correctly extracted project names among all names extracted by the function.
# - **Recall**: Measures how many of the actual project names were correctly extracted by the function.
# - **F1 Score**: A harmonic mean of precision and recall, useful when you want a balance between precision and recall.

# %%
import pandas as pd
from tqdm import tqdm
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

from services.content.project_identifier_service import ProjectIdentifierService
from project_name_extractor_utils import get_project_list
from dtos.project import Project

from importlib import reload
from dtos.identified_project import IdentifiedProject

# %%
ground_truth_csv_path = "/home/jovyan/work/notebook/project_name_extractor_evaluation/ground_truth.csv"

# %%
# Read Ground Truth CSV Data
data = pd.read_csv(ground_truth_csv_path, delimiter=";")

# Load the data into a DataFrame
df = pd.DataFrame(data)

# %% [markdown]
# Replace "NaN" with an empty string in the expected project names to avoid issues with comparison.

# %%
df = df.fillna("")

# %%
df
# Out:
#     source_system                            project_id  \
# 0            evdi  54EE27F7-BFB3-49BD-9438-2BE412C8D8A0
# 1            evdi  54EE27F7-BFB3-49BD-9438-2BE412C8D8A0
# 2            evdi  54EE27F7-BFB3-49BD-9438-2BE412C8D8A0
# 3            evdi  54EE27F7-BFB3-49BD-9438-2BE412C8D8A0
# 4            evdi  54EE27F7-BFB3-49BD-9438-2BE412C8D8A0
# ..            ...                                   ...
# 207          evdi
# 208          evdi
# 209          evdi
# 210          evdi
# 211          evdi
#
#                         project_name  \
# 0    DFI Zukunftspark Oberfranken VI
# 1    DFI Zukunftspark Oberfranken VI
# 2    DFI Zukunftspark Oberfranken VI
# 3    DFI Zukunftspark Oberfranken VI
# 4    DFI Zukunftspark Oberfranken VI
# ..                               ...
# 207
# 208
# 209
# 210
# 211
#
#                                                subject  \
# 0    Welche Sicherheiten bietet das Projekt DFI Zuk...
# 1    Wie ist die Verzinsung für Investoren im Proje...
# 2    Fragen zur Infrastruktur im Projekt DFI Zukunf...
# 3    Projektlaufzeit und Rückzahlung im DFI Zukunft...
# 4    Welche Sicherheiten gibt es im DFI Zukunftspar...
# ..                                                 ...
# 207                   Wann erfolgt die Zinsauszahlung?
# 208    Wann beginnt die Verzinsung meines Investments?
# 209  Welche Infrastrukturmaßnahmen sind im Projekt ...
# 210   Wann beginnt die Rückzahlung meines Investments?
# 211                   Wie werden die Zinsen berechnet?
#
#                                                   body
# 0    Können Sie mir bitte mitteilen, welche Sicherh...
# 1    Ich interessiere mich für die Verzinsung beim ...
# 2    Ich möchte wissen, welche infrastrukturellen E...
# 3    Wie lange ist die geplante Projektlaufzeit bei...
# 4    Mich würde interessieren, welche Sicherheiten ...
# ..                                                 ...
# 207  Wann werden die Zinszahlungen für mein Investm...
# 208  Wann beginnt die Verzinsung meiner Investition...
# 209  Welche Infrastrukturmaßnahmen werden im Rahmen...
# 210  Wann wird die Rückzahlung meines Investments e...
# 211  Wie erfolgt die Berechnung der Zinsen und wie ...
#
# [212 rows x 5 columns]

# %%
projects = get_project_list()
filtered_project_names = [project.name for project in projects if 'Spendenprojekt - Green Forest Fund' not in project.name]
project_identifier_service = ProjectIdentifierService(filtered_project_names)

# %%
filtered_project_names
# Out:
# ['DFI Zukunftspark Oberfranken VI',
#  'Berliner Flair in Friedrichshain II',
#  'DFI Zukunftspark Nordbayern IV',
#  'DFI Zukunftspark Oberfranken V',
#  'Am Akkonplatz',
#  'Berliner Flair in Friedrichshain',
#  'DFI Zukunftspark Oberfranken IV',
#  'Tonhallen-Passage II',
#  'DFI Zukunftspark Nordbayern III',
#  'DFI Zukunftspark Oberfranken III',
#  'DFI Zukunftspark Dreiländereck II',
#  'Friedrichstraße 191 III',
#  'Office am Europaring IV',
#  'DFI Zukunftspark Mittelfranken',
#  'Wohnquartier Pasing II',
#  'DFI Zukunftspark Dreiländereck',
#  'smart-UP Self-Storage-Park III',
#  'Stadthaus Mozart IV',
#  'Stadthaus Mozart III',
#  'Büro-Hochhaus am Scheidemannplatz II',
#  'smartUP Self-Storage-Park II',
#  'Jugendstil-Altbau am Rothenbaum II',
#  'Stadtleben Altlindenau',
#  'An der Kleinen Weser',
#  'Modernes Wohnen am Nymphenburger Kanal II',
#  'Atelier-Wohnungen an der Burg II',
#  'Eco Living Lichtenrade',
#  'The Five',
#  'Elegantes Wohnen nahe der Isar',
#  'Solarpark Eyendorf',
#  'DFI Zukunftspark Oberrhein II',
#  'DFI Zukunftspark Nordbayern II',
#  'Bürokomplex Alemannenhof III',
#  'DFI Zukunftspark Oberfranken II',
#  'Office am Europaring III',
#  'DFI Zukunftspark Oberfranken',
#  'OVUM Neue Mitte Braunsfeld II',
#  'DFI Zukunftspark Nordbayern',
#  "Stadthaus 'Mozart'",
#  "Stadthaus 'Mozart' II",
#  'Pracht-Altbau Sendlinger Tor II',
#  'Pracht-Altbau Sendlinger Tor']

# %%
for idx, row in tqdm(df.iterrows(), total=df.shape[0]):
    row_as_dict = row.to_dict()
    input_text = (row_as_dict["subject"] + " " + row_as_dict["body"]).strip()
    extracted_project: IdentifiedProject = project_identifier_service.extract_project(input_text)
    if extracted_project == None:
        df.at[idx, "extracted_project_name"] = ""
        continue

    df.at[idx, "extracted_project_name"] = extracted_project.name
    df.at[idx, "extracted_project_similarity"] = extracted_project.similarity
# Out:
# 100%|██████████| 212/212 [06:58<00:00,  1.98s/it]

# %%
df
# Out:
#     source_system                            project_id  \
# 0            evdi  54EE27F7-BFB3-49BD-9438-2BE412C8D8A0
# 1            evdi  54EE27F7-BFB3-49BD-9438-2BE412C8D8A0
# 2            evdi  54EE27F7-BFB3-49BD-9438-2BE412C8D8A0
# 3            evdi  54EE27F7-BFB3-49BD-9438-2BE412C8D8A0
# 4            evdi  54EE27F7-BFB3-49BD-9438-2BE412C8D8A0
# ..            ...                                   ...
# 207          evdi
# 208          evdi
# 209          evdi
# 210          evdi
# 211          evdi
#
#                         project_name  \
# 0    DFI Zukunftspark Oberfranken VI
# 1    DFI Zukunftspark Oberfranken VI
# 2    DFI Zukunftspark Oberfranken VI
# 3    DFI Zukunftspark Oberfranken VI
# 4    DFI Zukunftspark Oberfranken VI
# ..                               ...
# 207
# 208
# 209
# 210
# 211
#
#                                                subject  \
# 0    Welche Sicherheiten bietet das Projekt DFI Zuk...
# 1    Wie ist die Verzinsung für Investoren im Proje...
# 2    Fragen zur Infrastruktur im Projekt DFI Zukunf...
# 3    Projektlaufzeit und Rückzahlung im DFI Zukunft...
# 4    Welche Sicherheiten gibt es im DFI Zukunftspar...
# ..                                                 ...
# 207                   Wann erfolgt die Zinsauszahlung?
# 208    Wann beginnt die Verzinsung meines Investments?
# 209  Welche Infrastrukturmaßnahmen sind im Projekt ...
# 210   Wann beginnt die Rückzahlung meines Investments?
# 211                   Wie werden die Zinsen berechnet?
#
#                                                   body  \
# 0    Können Sie mir bitte mitteilen, welche Sicherh...
# 1    Ich interessiere mich für die Verzinsung beim ...
# 2    Ich möchte wissen, welche infrastrukturellen E...
# 3    Wie lange ist die geplante Projektlaufzeit bei...
# 4    Mich würde interessieren, welche Sicherheiten ...
# ..                                                 ...
# 207  Wann werden die Zinszahlungen für mein Investm...
# 208  Wann beginnt die Verzinsung meiner Investition...
# 209  Welche Infrastrukturmaßnahmen werden im Rahmen...
# 210  Wann wird die Rückzahlung meines Investments e...
# 211  Wie erfolgt die Berechnung der Zinsen und wie ...
#
#               extracted_project_name  extracted_project_similarity
# 0       DFI Zukunftspark Oberfranken                      0.414092
# 1    DFI Zukunftspark Oberfranken IV                      0.433192
# 2       DFI Zukunftspark Oberfranken                      0.494035
# 3    DFI Zukunftspark Oberfranken VI                      0.413225
# 4    DFI Zukunftspark Oberfranken VI                      0.482045
# ..                               ...                           ...
# 207                                                            NaN
# 208                                                            NaN
# 209                                                            NaN
# 210                                                            NaN
# 211                                                            NaN
#
# [212 rows x 7 columns]

# %%
# Ground truth and predictions
y_true = df['project_name']
y_pred = df['extracted_project_name']

# Compute metrics
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average="macro")
recall = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')

# Print results
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Accuracy: 0.7783018867924528
# Precision: 0.8923954277727862
# Recall: 0.7815476190476192
# F1 Score: 0.7950560021988593
# /home/jovyan/.local/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## Analyze the results

# %% [markdown]
# Find rows where the values are not the same

# %%
mask = df["project_name"] != df["extracted_project_name"]
different_values_df = df[mask]
len(different_values_df)
# Out:
# 47

# %%
different_values_df
# Out:
#     source_system                            project_id  \
# 0            evdi  54EE27F7-BFB3-49BD-9438-2BE412C8D8A0
# 1            evdi  54EE27F7-BFB3-49BD-9438-2BE412C8D8A0
# 2            evdi  54EE27F7-BFB3-49BD-9438-2BE412C8D8A0
# 12           evdi  E2FEFD3E-6841-434F-AF12-6E700D7C60D3
# 13           evdi  E2FEFD3E-6841-434F-AF12-6E700D7C60D3
# 14           evdi  E2FEFD3E-6841-434F-AF12-6E700D7C60D3
# 18           evdi  D1F21F84-9EEC-4D0B-A63A-BF656A28A256
# 19           evdi  D1F21F84-9EEC-4D0B-A63A-BF656A28A256
# 20           evdi  D1F21F84-9EEC-4D0B-A63A-BF656A28A256
# 23           evdi  D1F21F84-9EEC-4D0B-A63A-BF656A28A256
# 24           evdi  811DC8A3-C453-48A0-82DD-58DF3AD52A6D
# 25           evdi  811DC8A3-C453-48A0-82DD-58DF3AD52A6D
# 26           evdi  811DC8A3-C453-48A0-82DD-58DF3AD52A6D
# 27           evdi  811DC8A3-C453-48A0-82DD-58DF3AD52A6D
# 29           evdi  811DC8A3-C453-48A0-82DD-58DF3AD52A6D
# 31           evdi  83FF1D1C-6A7F-45BB-ADFF-0E42C26463A4
# 32           evdi  83FF1D1C-6A7F-45BB-ADFF-0E42C26463A4
# 33           evdi  83FF1D1C-6A7F-45BB-ADFF-0E42C26463A4
# 34           evdi  83FF1D1C-6A7F-45BB-ADFF-0E42C26463A4
# 35           evdi  83FF1D1C-6A7F-45BB-ADFF-0E42C26463A4
# 36           evdi  E6EA9000-8561-4F86-8795-A60032F239F4
# 38           evdi  E6EA9000-8561-4F86-8795-A60032F239F4
# 43           evdi  4973E74A-E88E-4E1B-B534-36615368D4A6
# 44           evdi  4973E74A-E88E-4E1B-B534-36615368D4A6
# 45           evdi  4973E74A-E88E-4E1B-B534-36615368D4A6
# 49           evdi  35F259F1-4160-4768-9C7A-9ECBDA485BA0
# 50           evdi  35F259F1-4160-4768-9C7A-9ECBDA485BA0
# 51           evdi  35F259F1-4160-4768-9C7A-9ECBDA485BA0
# 68           evdi  A0D1803B-9018-4774-82A4-AAB4668E19C6
# 76           evdi  8F43C311-FFC4-48FF-9FEC-96F2DA8006FD
# 77           evdi  8F43C311-FFC4-48FF-9FEC-96F2DA8006FD
# 81           evdi  9C0D39D1-E98B-4C90-BE38-A3C6CC02E79A
# 90           evdi  E391251B-C6C5-46D9-AA54-6B0385CC530C
# 100          evdi  4D8F9F51-556B-4AD5-8223-7F7B96F16EBE
# 104          evdi  4D8F9F51-556B-4AD5-8223-7F7B96F16EBE
# 106          evdi  180770C4-5FE2-481B-B2CF-6BEF10A9B400
# 107          evdi  180770C4-5FE2-481B-B2CF-6BEF10A9B400
# 112          evdi  04DF54CA-2B08-4545-ADD1-EA4D6301E993
# 114          evdi  04DF54CA-2B08-4545-ADD1-EA4D6301E993
# 127          evdi  964AEB7E-D162-4AD6-BBCB-8B238C6A047A
# 129          evdi  755DB000-4F7C-4AD6-A4A0-C7EA67B26C2E
# 130          evdi  755DB000-4F7C-4AD6-A4A0-C7EA67B26C2E
# 158          evdi  CC215696-CDDF-43B2-BB79-BD204EFD64F3
# 159          evdi  CC215696-CDDF-43B2-BB79-BD204EFD64F3
# 160          evdi  CC215696-CDDF-43B2-BB79-BD204EFD64F3
# 169          evdi  C0EFFCBA-AB7D-4DB2-BBBD-DA72EF272C7E
# 186          evdi  AFDD98B3-B93C-4803-8D60-FF1733217768
#
#                              project_name  \
# 0         DFI Zukunftspark Oberfranken VI
# 1         DFI Zukunftspark Oberfranken VI
# 2         DFI Zukunftspark Oberfranken VI
# 12         DFI Zukunftspark Nordbayern IV
# 13         DFI Zukunftspark Nordbayern IV
# 14         DFI Zukunftspark Nordbayern IV
# 18         DFI Zukunftspark Oberfranken V
# 19         DFI Zukunftspark Oberfranken V
# 20         DFI Zukunftspark Oberfranken V
# 23         DFI Zukunftspark Oberfranken V
# 24                          Am Akkonplatz
# 25                          Am Akkonplatz
# 26                          Am Akkonplatz
# 27                          Am Akkonplatz
# 29                          Am Akkonplatz
# 31       Berliner Flair in Friedrichshain
# 32       Berliner Flair in Friedrichshain
# 33       Berliner Flair in Friedrichshain
# 34       Berliner Flair in Friedrichshain
# 35       Berliner Flair in Friedrichshain
# 36        DFI Zukunftspark Oberfranken IV
# 38        DFI Zukunftspark Oberfranken IV
# 43                   Tonhallen-Passage II
# 44                   Tonhallen-Passage II
# 45                   Tonhallen-Passage II
# 49        DFI Zukunftspark Nordbayern III
# 50        DFI Zukunftspark Nordbayern III
# 51        DFI Zukunftspark Nordbayern III
# 68                Friedrichstraße 191 III
# 76         DFI Zukunftspark Mittelfranken
# 77         DFI Zukunftspark Mittelfranken
# 81                 Wohnquartier Pasing II
# 90         DFI Zukunftspark Dreiländereck
# 100                   Stadthaus Mozart IV
# 104                   Stadthaus Mozart IV
# 106                  Stadthaus Mozart III
# 107                  Stadthaus Mozart III
# 112  Büro-Hochhaus am Scheidemannplatz II
# 114  Büro-Hochhaus am Scheidemannplatz II
# 127                Stadtleben Altlindenau
# 129                  An der Kleinen Weser
# 130                  An der Kleinen Weser
# 158    Spendenprojekt - Green Forest Fund
# 159    Spendenprojekt - Green Forest Fund
# 160    Spendenprojekt - Green Forest Fund
# 169          DFI Zukunftspark Oberfranken
# 186                 Stadthaus 'Mozart' II
#
#                                                subject  \
# 0    Welche Sicherheiten bietet das Projekt DFI Zuk...
# 1    Wie ist die Verzinsung für Investoren im Proje...
# 2    Fragen zur Infrastruktur im Projekt DFI Zukunf...
# 12   Welche Rendite erwartet mich bei DFI Zukunftsp...
# 13   Wie sicher ist mein Investment bei DFI Zukunft...
# 14         Wie ist die Verzinsung für mein Investment?
# 18   Wie hoch ist der Zinssatz bei DFI Zukunftspark...
# 19   Wie sicher ist das Investment im Projekt DFI Z...
# 20                        Wann beginnt die Verzinsung?
# 23                   Erhalte ich steuerliche Vorteile?
# 24   Wie ist das Risiko beim Projekt Am Akkonplatz ...
# 25   Wie lange dauert die Finanzierung des Projekts...
# 26   Was für Sicherheiten gibt es bei diesem Invest...
# 27   Wie hoch ist die Rendite beim Projekt Am Akkon...
# 29             Wann beginnt die Auszahlung der Zinsen?
# 31   Renditeerwartungen und Laufzeit des Berliner F...
# 32   Infrastruktur und Nachhaltigkeit des Friedrich...
# 33   Detaillierte Informationen zur Investitionsstr...
# 34   Fragen zur rechtlichen Struktur und steuerlich...
# 35   Ausstiegsmöglichkeiten und Liquidität beim Ber...
# 36   Renditeaussichten für DFI Zukunftspark Oberfra...
# 38   Fragen zur Projektlaufzeit und Auszahlungsmoda...
# 43   Sicherheitsaspekte und Risikoabsicherung des P...
# 44   Fragen zur Projektdauer und Auszahlungsmodalit...
# 45   Nachhaltigkeitskonzept und energetische Sanierung
# 49   Fragen zur Finanzierungsstruktur und Mindestbe...
# 50   Infrastrukturelle Bedeutung und wirtschaftlich...
# 51   Rechtliche und steuerliche Aspekte der Investi...
# 68             Welche Rückzahlungsmodalitäten gibt es?
# 76   Infrastrukturelle Bedeutung und wirtschaftlich...
# 77   Rechtliche und steuerliche Aspekte der Investi...
# 81   Fragen zur Projektlaufzeit und Auszahlungsmoda...
# 90   Detaillierte Informationen zur Projektdauer un...
# 100  Sicherheitsaspekte beim Stadthaus Mozart IV Pr...
# 104    Finanzierungsstruktur und Investorenbeteiligung
# 106  Sicherheitskonzept und Risikoanalyse der Inves...
# 107                 Standortanalyse und Marktpotenzial
# 112  Nachhaltigkeit und Energieeffizienz bei Büropr...
# 114  Sicherheiten und Risikoabsicherung beim Immobi...
# 127  Wie lange dauert die Finanzierung des Projekts...
# 129  Welche Rendite kann ich beim Projekt An der Kl...
# 130  Wie lange dauert die Finanzierung des Projekts...
# 158  Wie wird die Rendite beim Spendenprojekt - Gre...
# 159  Wie hoch ist das Risiko für das Spendenprojekt...
# 160                   Sicherheit und Renditepotenzial?
# 169  Wie hoch ist die erwartete Rendite beim DFI Zu...
# 186    Welche Absicherung gibt es für die Investition?
#
#                                                   body  \
# 0    Können Sie mir bitte mitteilen, welche Sicherh...
# 1    Ich interessiere mich für die Verzinsung beim ...
# 2    Ich möchte wissen, welche infrastrukturellen E...
# 12   Ich würde gerne wissen, welche Rendite ich bei...
# 13   Könnten Sie mir bitte Informationen zu den Sic...
# 14   Ich würde gerne mehr über die Verzinsung bei m...
# 18   Ich möchte wissen, welcher Zinssatz bei meinem...
# 19   Welche Sicherheitsmaßnahmen gibt es für dieses...
# 20   Wann genau startet die Verzinsung meines Inves...
# 23   Ich habe gehört, dass das Projekt DFI Zukunfts...
# 24   Wie wird das Risiko bei diesem Investment eing...
# 25   Könnten Sie mir bitte mitteilen, wie lange die...
# 26   Welche Sicherheiten bietet das Projekt Am Akko...
# 27   Welche Rendite kann ich bei einer Investition ...
# 29   Ich möchte wissen, ab wann die Verzinsung mein...
# 31   Guten Tag, ich habe großes Interesse an einer ...
# 32   Sehr geehrtes Projektteam, ich beschäftige mic...
# 33   Liebe Projektverantwortliche, ich interessiere...
# 34   Sehr geehrte Damen und Herren, als potenzielle...
# 35   Guten Tag, ich erwäge eine Investition in das ...
# 36   Sehr geehrte Damen und Herren, ich interessier...
# 38   Sehr geehrtes Projektteam, ich habe einige Fra...
# 43   Guten Tag, als potenzieller Investor möchte ic...
# 44   Sehr geehrtes Projektteam, ich habe einige Fra...
# 45   Liebe Projektverantwortliche, als umweltbewuss...
# 49   Sehr geehrtes Projektteam, ich beschäftige mic...
# 50   Liebe Projektverantwortliche, als potenzieller...
# 51   Sehr geehrte Damen und Herren, ich habe einige...
# 68   Welche Rückzahlungsmodalitäten sind für mein I...
# 76   Liebe Projektverantwortliche, als potenzieller...
# 77   Sehr geehrte Damen und Herren, ich habe einige...
# 81   Sehr geehrtes Projektteam, ich habe einige Fra...
# 90   Sehr geehrtes Projektteam, ich interessiere mi...
# 100  Guten Tag, als potenzieller Investor möchte ic...
# 104  Sehr geehrte Damen und Herren, ich würde gerne...
# 106  Guten Tag, als potenzieller Investor möchte ic...
# 107  Sehr geehrte Damen und Herren, ich interessier...
# 112  Guten Tag, ich habe eine Frage bezüglich der N...
# 114  Sehr geehrte Damen und Herren, als potenzielle...
# 127  Könnten Sie mir bitte mitteilen, wie lange die...
# 129  Welche Rendite ist bei einer Investition in da...
# 130  Könnten Sie mir bitte die geplante Laufzeit de...
# 158  Wie wird die Rendite in diesem Projekt berechn...
# 159  Wie wird das Risiko dieses Projekts bewertet u...
# 160  Welche Sicherheitsmaßnahmen gibt es beim Green...
# 169  Welche Rendite kann ich bei dieser Investition...
# 186  Ich würde gerne mehr über die Sicherheit des P...
#
#                   extracted_project_name  extracted_project_similarity
# 0           DFI Zukunftspark Oberfranken                      0.414092
# 1        DFI Zukunftspark Oberfranken IV                      0.433192
# 2           DFI Zukunftspark Oberfranken                      0.494035
# 12        DFI Zukunftspark Nordbayern II                      0.426020
# 13        DFI Zukunftspark Nordbayern II                      0.428162
# 14        DFI Zukunftspark Nordbayern II                      0.361636
# 18       DFI Zukunftspark Oberfranken IV                      0.401171
# 19       DFI Zukunftspark Oberfranken IV                      0.351459
# 20       DFI Zukunftspark Oberfranken IV                      0.287431
# 23       DFI Zukunftspark Oberfranken IV                      0.405782
# 24                                                                 NaN
# 25                                                                 NaN
# 26                                                                 NaN
# 27                                                                 NaN
# 29                                                                 NaN
# 31                                                                 NaN
# 32   Berliner Flair in Friedrichshain II                      0.232458
# 33                                                                 NaN
# 34                                                                 NaN
# 35   Berliner Flair in Friedrichshain II                      0.329374
# 36       DFI Zukunftspark Oberfranken II                      0.366484
# 38                                                                 NaN
# 43                                                                 NaN
# 44                                                                 NaN
# 45                                                                 NaN
# 49        DFI Zukunftspark Nordbayern IV                      0.290969
# 50        DFI Zukunftspark Nordbayern IV                      0.262287
# 51        DFI Zukunftspark Nordbayern IV                      0.223672
# 68                                                                 NaN
# 76                                                                 NaN
# 77                                                                 NaN
# 81                                                                 NaN
# 90                                                                 NaN
# 100                                                                NaN
# 104                                                                NaN
# 106                                                                NaN
# 107                                                                NaN
# 112                                                                NaN
# 114                                                                NaN
# 127                                                                NaN
# 129                                                                NaN
# 130                                                                NaN
# 158                                                                NaN
# 159                                                                NaN
# 160                                                                NaN
# 169      DFI Zukunftspark Oberfranken II                      0.378690
# 186                   Stadthaus 'Mozart'                      0.207068

# %% [markdown]
# Let's investigate some of them:

# %%
expected_project_name = "Am Akkonplatz"
input_text = "Wie ist das Risiko beim Projekt Am Akkonplatz eingeschätzt? Wie wird das Risiko bei diesem Investment eingeschätzt? Gibt es Schutzmechanismen, um mein Kapital zu sichern, falls das Projekt nicht erfolgreich ist?"

extracted_project = project_identifier_service.extract_project(input_text)
extracted_project

# %%
expected_project_name = "Wohnquartier Pasing II"
input_text = "Fragen zur Projektlaufzeit und Auszahlungsmodalitäten Sehr geehrtes Projektteam, ich habe einige Fragen bezüglich der zeitlichen Aspekte und Auszahlungsmodalitäten des Investments. Wie lange ist die geplante Laufzeit des Wohnprojekts in Pasing? Ab wann können Investoren mit den ersten Ausschüttungen rechnen? Gibt es einen festen Auszahlungsplan oder sind die Zahlungen an bestimmte Meilensteine im Bauprozess geknüpft? Besteht die Möglichkeit einer vorzeitigen Kündigung oder eines Verkaufs der Anteile? Ich würde mich über detaillierte Informationen zu diesen Punkten sehr freuen, da sie für meine Investitionsplanung von großer Bedeutung sind. Das Projekt ist Wohnquartier Pasing II"

extracted_project = project_identifier_service.extract_project(input_text)
extracted_project

# %%
expected_project_name = "Büro-Hochhaus am Scheidemannplatz II"
input_text = "Sicherheiten und Risikoabsicherung beim Immobilieninvestment Sehr geehrte Damen und Herren, als potenzieller Investor möchte ich mich nach den Sicherheiten erkundigen, die Sie für Investments in Ihr Projekt bieten. Welche konkreten Maßnahmen haben Sie ergriffen, um das Risiko für Investoren zu minimieren? Gibt es eine Absicherung durch Grundbucheinträge oder andere rechtliche Konstrukte? Mich würde auch interessieren, wie Sie mit möglichen Verzögerungen im Bauprozess oder unerwarteten Kostensteigerungen umgehen. Beim Projekt Büro-Hochhaus am Scheidemannplatz II, wie stellen Sie sicher, dass die Interessen der Investoren gewahrt bleiben?"

extracted_project = project_identifier_service.extract_project(input_text)
extracted_project

# %% [markdown]
# Check how many unique project names are in the dataset and how often they appear:

# %%
print(df['project_name'].value_counts())
# Out:
# project_name
#                                              24
# DFI Zukunftspark Dreiländereck                8
# DFI Zukunftspark Nordbayern IV                6
# DFI Zukunftspark Oberfranken V                6
# Am Akkonplatz                                 6
# Berliner Flair in Friedrichshain              6
# DFI Zukunftspark Oberfranken IV               6
# DFI Zukunftspark Nordbayern III               6
# DFI Zukunftspark Oberfranken VI               6
# Berliner Flair in Friedrichshain II           6
# smartUP Self-Storage-Park II                  6
# DFI Zukunftspark Oberfranken III              6
# Wohnquartier Pasing II                        6
# DFI Zukunftspark Dreiländereck II             6
# smart-UP Self-Storage-Park III                6
# Stadthaus Mozart IV                           6
# Büro-Hochhaus am Scheidemannplatz II          6
# DFI Zukunftspark Mittelfranken                6
# Stadthaus Mozart III                          6
# Tonhallen-Passage II                          5
# Stadthaus 'Mozart'                            5
# Stadthaus 'Mozart' II                         5
# The Five                                      4
# Office am Europaring IV                       4
# Friedrichstraße 191 III                       4
# Atelier-Wohnungen an der Burg II              4
# Modernes Wohnen am Nymphenburger Kanal II     3
# An der Kleinen Weser                          3
# Stadtleben Altlindenau                        3
# Jugendstil-Altbau am Rothenbaum II            3
# DFI Zukunftspark Oberrhein II                 3
# Eco Living Lichtenrade                        3
# Elegantes Wohnen nahe der Isar                3
# Solarpark Eyendorf                            3
# Bürokomplex Alemannenhof III                  3
# Spendenprojekt - Green Forest Fund            3
# DFI Zukunftspark Nordbayern II                3
# Office am Europaring III                      3
# DFI Zukunftspark Oberfranken                  3
# OVUM Neue Mitte Braunsfeld II                 3
# DFI Zukunftspark Nordbayern                   3
# DFI Zukunftspark Oberfranken II               2
# Name: count, dtype: int64

# %% [markdown]
# Compare Predictions and Ground Truth:

# %%
mismatches = df[df['project_name'] != df['extracted_project_name']]
print(mismatches[['project_name', 'extracted_project_name']])
# Out:
#                              project_name               extracted_project_name
# 0         DFI Zukunftspark Oberfranken VI         DFI Zukunftspark Oberfranken
# 1         DFI Zukunftspark Oberfranken VI      DFI Zukunftspark Oberfranken IV
# 2         DFI Zukunftspark Oberfranken VI         DFI Zukunftspark Oberfranken
# 12         DFI Zukunftspark Nordbayern IV       DFI Zukunftspark Nordbayern II
# 13         DFI Zukunftspark Nordbayern IV       DFI Zukunftspark Nordbayern II
# 14         DFI Zukunftspark Nordbayern IV       DFI Zukunftspark Nordbayern II
# 18         DFI Zukunftspark Oberfranken V      DFI Zukunftspark Oberfranken IV
# 19         DFI Zukunftspark Oberfranken V      DFI Zukunftspark Oberfranken IV
# 20         DFI Zukunftspark Oberfranken V      DFI Zukunftspark Oberfranken IV
# 23         DFI Zukunftspark Oberfranken V      DFI Zukunftspark Oberfranken IV
# 24                          Am Akkonplatz
# 25                          Am Akkonplatz
# 26                          Am Akkonplatz
# 27                          Am Akkonplatz
# 29                          Am Akkonplatz
# 31       Berliner Flair in Friedrichshain
# 32       Berliner Flair in Friedrichshain  Berliner Flair in Friedrichshain II
# 33       Berliner Flair in Friedrichshain
# 34       Berliner Flair in Friedrichshain
# 35       Berliner Flair in Friedrichshain  Berliner Flair in Friedrichshain II
# 36        DFI Zukunftspark Oberfranken IV      DFI Zukunftspark Oberfranken II
# 38        DFI Zukunftspark Oberfranken IV
# 43                   Tonhallen-Passage II
# 44                   Tonhallen-Passage II
# 45                   Tonhallen-Passage II
# 49        DFI Zukunftspark Nordbayern III       DFI Zukunftspark Nordbayern IV
# 50        DFI Zukunftspark Nordbayern III       DFI Zukunftspark Nordbayern IV
# 51        DFI Zukunftspark Nordbayern III       DFI Zukunftspark Nordbayern IV
# 68                Friedrichstraße 191 III
# 76         DFI Zukunftspark Mittelfranken
# 77         DFI Zukunftspark Mittelfranken
# 81                 Wohnquartier Pasing II
# 90         DFI Zukunftspark Dreiländereck
# 100                   Stadthaus Mozart IV
# 104                   Stadthaus Mozart IV
# 106                  Stadthaus Mozart III
# 107                  Stadthaus Mozart III
# 112  Büro-Hochhaus am Scheidemannplatz II
# 114  Büro-Hochhaus am Scheidemannplatz II
# 127                Stadtleben Altlindenau
# 129                  An der Kleinen Weser
# 130                  An der Kleinen Weser
# 158    Spendenprojekt - Green Forest Fund
# 159    Spendenprojekt - Green Forest Fund
# 160    Spendenprojekt - Green Forest Fund
# 169          DFI Zukunftspark Oberfranken      DFI Zukunftspark Oberfranken II
# 186                 Stadthaus 'Mozart' II                   Stadthaus 'Mozart'

# %% [markdown]
# ## Examine Confusion Matrix
# The **confusion matrix** is an important tool to evaluate the performance of a classification model. It provides a detailed breakdown of how the model's predictions compare to the actual results, allowing you to pinpoint where your model performs well and where it makes mistakes.
#
# #### **What is a Confusion Matrix?**
# A **confusion matrix** is a table that shows the actual versus predicted classifications. It helps you see how many times the model correctly predicted each class and where it made errors. For each class (in your case, a project name), the matrix tracks four important types of predictions:
# 1. **True Positives (TP)**: Correct predictions where the model predicted a class and it was actually that class.
# 2. **False Positives (FP)**: Incorrect predictions where the model predicted a class, but it should have predicted a different class.
# 3. **False Negatives (FN)**: Missed predictions where the model failed to predict a class that was the actual class.
# 4. **True Negatives (TN)**: Correct rejections where the model correctly predicted a different class.
#
# For **multiclass classification**, the confusion matrix will be larger, showing a grid where the rows represent the **actual labels** and the columns represent the **predicted labels**.
#
# #### **Structure of a Confusion Matrix**
# For your use case, where you're classifying project names, the confusion matrix will look something like this:
#
# |                | Predicted: Project A | Predicted: Project B | Predicted: Project C |
# |----------------|----------------------|----------------------|----------------------|
# | Actual: Project A | TP (Correct)         | FP (Incorrect)        | FP (Incorrect)        |
# | Actual: Project B | FN (Miss)            | TP (Correct)         | FP (Incorrect)        |
# | Actual: Project C | FN (Miss)            | FN (Miss)            | TP (Correct)          |
#
# - **Diagonal elements** (from top-left to bottom-right) represent **True Positives (TP)**—correct predictions.
# - **Off-diagonal elements** (the other cells) represent errors, either **False Positives (FP)** or **False Negatives (FN)**.

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_true, y_pred, labels=df['project_name'].unique())
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=df['project_name'].unique(), yticklabels=df['project_name'].unique())
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %% [markdown]
# ## **How to Use the Confusion Matrix to Improve Results**
# 1. **Identify Specific Errors**:
#    - The confusion matrix tells you which project names the model confuses with each other. For example, if `Project A` is frequently misclassified as `Project B`, you can investigate why this happens. Is there a pattern in the data that leads to these confusions? Do `Project A` and `Project B` have similar names, or do the email bodies have similar content?
#
# 2. **Class Imbalance**:
#    - If you see that some projects are misclassified more often than others, it might indicate a **class imbalance**. In this case, you can consider techniques like **oversampling** the minority class (rare projects) or **undersampling** the majority class (frequent projects).
#
# 3. **Model Tuning**:
#    - The confusion matrix helps you focus on **precision and recall** for individual classes. If a particular class (project) has a low recall (many false negatives), you can adjust the threshold for classification to be more sensitive to that class. Similarly, if precision is low, you might want to make the model more conservative about predicting that class.
#
# 4. **Feature Engineering**:
#    - If specific classes are frequently misclassified, you might need to refine your **text extraction function** to better distinguish between them. For instance, you can extract additional features from the email content (like keywords, entities, or semantic context) to improve the classifier’s accuracy.

# %% [markdown]
# ## The similarity of the project names

# %%
mask = df["project_name"] == df["extracted_project_name"]
correct_predicted_values = df[mask]

correct_predicted_values
# Out:
#     source_system                            project_id  \
# 3            evdi  54EE27F7-BFB3-49BD-9438-2BE412C8D8A0
# 4            evdi  54EE27F7-BFB3-49BD-9438-2BE412C8D8A0
# 5            evdi  54EE27F7-BFB3-49BD-9438-2BE412C8D8A0
# 6            evdi  716867B4-C28C-425E-94BE-59886D853D49
# 7            evdi  716867B4-C28C-425E-94BE-59886D853D49
# ..            ...                                   ...
# 207          evdi
# 208          evdi
# 209          evdi
# 210          evdi
# 211          evdi
#
#                             project_name  \
# 3        DFI Zukunftspark Oberfranken VI
# 4        DFI Zukunftspark Oberfranken VI
# 5        DFI Zukunftspark Oberfranken VI
# 6    Berliner Flair in Friedrichshain II
# 7    Berliner Flair in Friedrichshain II
# ..                                   ...
# 207
# 208
# 209
# 210
# 211
#
#                                                subject  \
# 3    Projektlaufzeit und Rückzahlung im DFI Zukunft...
# 4    Welche Sicherheiten gibt es im DFI Zukunftspar...
# 5    Verzinsung und Projektdauer im DFI Zukunftspar...
# 6    Verkaufspreise für Wohnungen im Berliner Flair...
# 7    Wie hoch sind die Zinsen im Berliner Flair in ...
# ..                                                 ...
# 207                   Wann erfolgt die Zinsauszahlung?
# 208    Wann beginnt die Verzinsung meines Investments?
# 209  Welche Infrastrukturmaßnahmen sind im Projekt ...
# 210   Wann beginnt die Rückzahlung meines Investments?
# 211                   Wie werden die Zinsen berechnet?
#
#                                                   body  \
# 3    Wie lange ist die geplante Projektlaufzeit bei...
# 4    Mich würde interessieren, welche Sicherheiten ...
# 5    Können Sie mir die Details zur Verzinsung und ...
# 6    Ich würde gerne mehr über die geplanten Verkau...
# 7    Welche Verzinsung bietet das Projekt Berliner ...
# ..                                                 ...
# 207  Wann werden die Zinszahlungen für mein Investm...
# 208  Wann beginnt die Verzinsung meiner Investition...
# 209  Welche Infrastrukturmaßnahmen werden im Rahmen...
# 210  Wann wird die Rückzahlung meines Investments e...
# 211  Wie erfolgt die Berechnung der Zinsen und wie ...
#
#                   extracted_project_name  extracted_project_similarity
# 3        DFI Zukunftspark Oberfranken VI                      0.413225
# 4        DFI Zukunftspark Oberfranken VI                      0.482045
# 5        DFI Zukunftspark Oberfranken VI                      0.475351
# 6    Berliner Flair in Friedrichshain II                      0.479871
# 7    Berliner Flair in Friedrichshain II                      0.524845
# ..                                   ...                           ...
# 207                                                                NaN
# 208                                                                NaN
# 209                                                                NaN
# 210                                                                NaN
# 211                                                                NaN
#
# [165 rows x 7 columns]

# %%
similarity_min = df["extracted_project_similarity"].min()
similarity_min
# Out:
# np.float64(0.20706817507743835)

# %%
df["extracted_project_similarity"].describe()
# Out:
# count    159.000000
# mean       0.367275
# std        0.095441
# min        0.207068
# 25%        0.285589
# 50%        0.357564
# 75%        0.431852
# max        0.602253
# Name: extracted_project_similarity, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter out rows where 'extracted_project_similarity' is NaN
df_filtered = correct_predicted_values[correct_predicted_values["extracted_project_similarity"].notna()]

# Set the figure size
plt.figure(figsize=(12, 10))

# Create a box plot
sns.boxplot(x="extracted_project_name", y="extracted_project_similarity", data=df_filtered)

# Optionally, create a violin plot instead of a box plot
# sns.violinplot(x="extracted_project_name", y="extracted_project_similarity", data=df_filtered)

# Rotate x-axis labels for better readability
plt.xticks(rotation=90)

# Set plot title and labels
plt.title("Distribution of Extracted Project Similarity Across Extracted Project Names")
plt.xlabel("Extracted Project Name")
plt.ylabel("Extracted Project Similarity")

# Show the plot
plt.show()
